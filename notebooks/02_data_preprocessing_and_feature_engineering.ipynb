# %%
# notebooks/02_data_preprocessing_and_feature_engineering.ipynb

import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Load GANDOUR dataset
df = pd.read_excel("../data/GANDOUR_SALES_DATA.xlsx")

# Drop duplicates
df.drop_duplicates(inplace=True)

# Fill missing values
df.fillna(method="ffill", inplace=True)

# Encode categorical columns
cat_cols = df.select_dtypes(include="object").columns
le = LabelEncoder()
for col in cat_cols:
    df[col] = le.fit_transform(df[col])

# Scale numeric features
num_cols = df.select_dtypes(include="number").columns
scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

# Save cleaned version
df.to_csv("../data/cleaned_gandour_sales.csv", index=False)
# Out:
# C:\Users\Etudiant\AppData\Local\Temp\ipykernel_15988\1792105598.py:13: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
