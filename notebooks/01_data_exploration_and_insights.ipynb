# %%
# =====================================================
# Project: Sales Forecasting - GANDOUR Côte d'Ivoire
# Step: 01 - Data Exploration and Initial Insights
# =====================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Notebook display settings
pd.set_option("display.max_columns", None)
sns.set(style="whitegrid")
# %matplotlib inline

# Load dataset
file_path = "../data/GANDOUR_SALES_DATA.xlsx"
if os.path.exists(file_path):
    df = pd.read_excel(file_path)
    print(" Dataset loaded successfully.")
else:
    raise FileNotFoundError(f" File not found at {file_path}")

# Overview
print("Shape:", df.shape)
display(df.head())
display(df.info())
display(df.describe(include='all'))

# Missing values
print("Missing values:\n", df.isnull().sum())
plt.figure(figsize=(10, 5))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Missing Values Overview")
plt.show()

# Unique values per column
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# ✅ Dataset loaded successfully.
# Shape: (83006, 16)
#   type       date                                 product code_product  \
# 0  Out 2024-03-01        GANDOUR LAIT DBD MEN CLASSIC 500    HYDMLA500
# 1  Out 2024-03-01        GANDOUR LAIT DBD MEN CLASSIC 500    HYDMLA500
# 2  Out 2024-03-01        GANDOUR LAIT DBD MEN CLASSIC 500    HYDMLA500
# 3  Out 2024-03-01        GANDOUR LAIT DBD MEN CLASSIC 500    HYDMLA500
# 4  Out 2024-03-01  GANDOUR CREME PERFECTWHITE 300mlx24pcs    ECPWCR300
#
#   product_family  quantity location warehouse    bl     order_type    lot  \
# 0             HY        73   10B040       DPF  PINK  Delivery Note  14526
# 1             HY        73   10C007       DPF  PINK  Delivery Note  14343
# 2             HY        52   10D005       DPF  PINK  Delivery Note  14347
# 3             HY         3   10A019       DPF  PINK  Delivery Note  14430
# 4             EC        60   10E045       DPF  BLUE  Delivery Note  14321
#
#    id_client    client        region sales_channel                  company
# 0     1150.0  DIMD LDA       Abidjan      Boutique  GANDOUR - Côte d'Ivoire
# 1     1150.0  DIMD LDA  Yamoussoukro     Grossiste  GANDOUR - Côte d'Ivoire
# 2     1150.0  DIMD LDA        Bouaké   Supermarché  GANDOUR - Côte d'Ivoire
# 3     1150.0  DIMD LDA     San Pedro     Pharmacie  GANDOUR - Côte d'Ivoire
# 4     1150.0  DIMD LDA       Abidjan      Boutique  GANDOUR - Côte d'Ivoire
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83006 entries, 0 to 83005
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   type            83006 non-null  object
#  1   date            83006 non-null  datetime64[ns]
#  2   product         83006 non-null  object
#  3   code_product    83006 non-null  object
#  4   product_family  83006 non-null  object
#  5   quantity        83006 non-null  int64
#  6   location        83006 non-null  object
#  7   warehouse       78999 non-null  object
#  8   bl              63979 non-null  object
#  9   order_type      83006 non-null  object
#  10  lot             83006 non-null  object
#  11  id_client       63967 non-null  float64
#  12  client          63979 non-null  object
#  13  region          83006 non-null  object
#  14  sales_channel   83006 non-null  object
#  15  company         83006 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(13)
# memory usage: 10.1+ MB
# None
#          type                           date                        product  \
# count   83006                          83006                          83006
# unique      2                            NaN                            764
# top       Out                            NaN  GANDOUR SAC BABYMED  x 12 pcs
# freq    63979                            NaN                           1363
# mean      NaN  2024-03-30 01:20:06.823603456                            NaN
# min       NaN            2024-03-01 00:00:00                            NaN
# 25%       NaN            2024-03-13 00:00:00                            NaN
# 50%       NaN            2024-03-29 00:00:00                            NaN
# 75%       NaN            2024-04-17 00:00:00                            NaN
# max       NaN            2024-04-29 00:00:00                            NaN
# std       NaN                            NaN                            NaN
#
#        code_product product_family      quantity location warehouse      bl  \
# count         83006          83006  83006.000000    83006     78999   63979
# unique          764              6           NaN     9976         2    2001
# top         BBBMSAC             EC           NaN   48A011       DPF  EXPORT
# freq           1363          30589           NaN       93     60354     630
# mean            NaN            NaN     20.425596      NaN       NaN     NaN
# min             NaN            NaN      1.000000      NaN       NaN     NaN
# 25%             NaN            NaN      2.000000      NaN       NaN     NaN
# 50%             NaN            NaN      9.000000      NaN       NaN     NaN
# 75%             NaN            NaN     40.000000      NaN       NaN     NaN
# max             NaN            NaN    186.000000      NaN       NaN     NaN
# std             NaN            NaN     23.694494      NaN       NaN     NaN
#
#        order_type    lot     id_client            client   region  \
# count       83006  83006  63967.000000             63979    83006
# unique          3   4377           NaN               162        4
# top       Invoice    SAV           NaN  MAGASIN OSSEILI   Abidjan
# freq        48512  17773           NaN              4124    20752
# mean          NaN    NaN   1500.926728               NaN      NaN
# min           NaN    NaN      8.000000               NaN      NaN
# 25%           NaN    NaN     73.000000               NaN      NaN
# 50%           NaN    NaN   1012.000000               NaN      NaN
# 75%           NaN    NaN   3183.000000               NaN      NaN
# max           NaN    NaN   4090.000000               NaN      NaN
# std           NaN    NaN   1516.857788               NaN      NaN
#
#        sales_channel                  company
# count          83006                    83006
# unique             4                        1
# top         Boutique  GANDOUR - Côte d'Ivoire
# freq           20752                    83006
# mean             NaN                      NaN
# min              NaN                      NaN
# 25%              NaN                      NaN
# 50%              NaN                      NaN
# 75%              NaN                      NaN
# max              NaN                      NaN
# std              NaN                      NaN
# Missing values:
#  type                  0
# date                  0
# product               0
# code_product          0
# product_family        0
# quantity              0
# location              0
# warehouse          4007
# bl                19027
# order_type            0
# lot                   0
# id_client         19039
# client            19027
# region                0
# sales_channel         0
# company               0
# dtype: int64
# type: 2 unique values
# date: 50 unique values
# product: 764 unique values
# code_product: 764 unique values
# product_family: 6 unique values
# quantity: 153 unique values
# location: 9976 unique values
# warehouse: 2 unique values
# bl: 2001 unique values
# order_type: 3 unique values
# lot: 4377 unique values
# id_client: 185 unique values
# client: 162 unique values
# region: 4 unique values
# sales_channel: 4 unique values
# company: 1 unique values
